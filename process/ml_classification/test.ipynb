# %%
import pandas as pd
import numpy as np
import random

df = pd.DataFrame(np.array([random.randint(0,100) for _ in range(75)]).reshape(-1,3), columns=['a','b','c'])
df
# Out:
#      a   b   c
# 0   29  10  55
# 1   80   7  52
# 2   59  87  42
# 3    4  19   1
# 4   65  93  16
# 5    9  56  53
# 6   69  88   0
# 7   29  27  86
# 8   37  70  69
# 9   61  90   5
# 10  69  25  87
# 11  82  14  56
# 12  75  14  82
# 13  59  52  47
# 14  61  35  77
# 15  41  28  26
# 16  48  33  27
# 17  91  67  59
# 18  31  49  89
# 19  48  84  78
# 20  69  22  16
# 21  87  35  57
# 22  74   7  23
# 23  97  83  38
# 24  57   5  11
